# %% [markdown]
# ## Bart Project

# %%
import pandas as pd

# %%
df16 = pd.read_csv('/content/date-hour-soo-dest-2016.csv')

# %%
df16.head()
# Out:
#   Origin Destination  Throughput             DateTime
# 0   12TH        12TH           1  2016-01-01 00:00:00
# 1   12TH        16TH           1  2016-01-01 00:00:00
# 2   12TH        24TH           4  2016-01-01 00:00:00
# 3   12TH        ASHB           4  2016-01-01 00:00:00
# 4   12TH        BALB           2  2016-01-01 00:00:00

# %%
df16.shape
# Out:
# (9971582, 4)

# %%
df16.isnull().sum()
# Out:
# Origin         0
# Destination    0
# Throughput     0
# DateTime       0
# dtype: int64

# %%
df16['DateTime'].nunique()
# Out:
# 8186

# %%
df16['Origin'].nunique()
# Out:
# 46

# %%
df16['Destination'].nunique()
# Out:
# 46

# %%
df16['Throughput'].nunique()
# Out:
# 915

# %%
df17 = pd.read_csv('/content/date-hour-soo-dest-2017.csv')

# %%
df17.head()
# Out:
#   Origin Destination  Throughput             DateTime
# 0   12TH        19TH           1  2017-01-01 00:00:00
# 1   12TH        24TH           2  2017-01-01 00:00:00
# 2   12TH        BAYF           1  2017-01-01 00:00:00
# 3   12TH        CIVC           5  2017-01-01 00:00:00
# 4   12TH        COLS           2  2017-01-01 00:00:00

# %%
df17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3313625 entries, 0 to 3313624
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Origin       object
#  1   Destination  object
#  2   Throughput   int64
#  3   DateTime     object
# dtypes: int64(1), object(3)
# memory usage: 101.1+ MB

# %%
df17['DateTime'].nunique()
# Out:
# 2776

# %%
df17['Origin'].nunique()
# Out:
# 46

# %%
df17['Destination'].nunique()
# Out:
# 46

# %%
df17['Throughput'].nunique()
# Out:
# 868

# %%
dfinfo= pd.read_csv('/content/station_info.csv')

# %%
dfinfo.head()
# Out:
#   Abbreviation                                        Description  \
# 0         12TH  1245 Broadway, Oakland CA 94612<br />12th St. ...
# 1         16TH  2000 Mission Street, San Francisco CA 94110<br...
# 2         19TH  1900 Broadway, Oakland CA 94612<br />19th Stre...
# 3         24TH  2800 Mission Street, San Francisco CA 94110<br...
# 4         ASHB  3100 Adeline Street, Berkeley CA 94703<br />As...
#
#                   Location                                 Name
# 0  -122.271450,37.803768,0  12th St. Oakland City Center (12TH)
# 1  -122.419694,37.765062,0              16th St. Mission (16TH)
# 2  -122.268602,37.808350,0              19th St. Oakland (19TH)
# 3  -122.418143,37.752470,0              24th St. Mission (24TH)
# 4  -122.270062,37.852803,0                         Ashby (ASHB)

# %%
dfinfo['Description'][1]
# Out:
# '2000 Mission Street, San Francisco CA 94110<br />"The Mission" refers to the San Francisco de Asis Mission, also known as Mission Dolores, which was founded 1776. Today the neighborhood is host to an eclectic mix of restaurants, markets, performance spaces, shops, and nightspots.'

# %%
dfinfo['Description'][2]
# Out:
# '1900 Broadway, Oakland CA 94612<br />19th Street Station is in the heart of Uptown Oakland near the historic Paramount Theater on Broadway.'

# %%
# İki veri setini birleştirelim
df = pd.concat([df16, df17], ignore_index=True)

# Birleştirilen verilerin ilk birkaç satırına bakalım
df.head()
# Out:
#   Origin Destination  Throughput             DateTime
# 0   12TH        12TH           1  2016-01-01 00:00:00
# 1   12TH        16TH           1  2016-01-01 00:00:00
# 2   12TH        24TH           4  2016-01-01 00:00:00
# 3   12TH        ASHB           4  2016-01-01 00:00:00
# 4   12TH        BALB           2  2016-01-01 00:00:00

# %%
# Tarih ve saat bilgisini ayrıştırma
df['DateTime'] = pd.to_datetime(df['DateTime'])
df['date'] = df['DateTime'].dt.date
df['hour'] = df['DateTime'].dt.hour
df['day_of_week'] = df['DateTime'].dt.day_name()

# İlk birkaç satırı kontrol etme
df.head()
# Out:
#   Origin Destination  Throughput   DateTime        date  hour day_of_week
# 0   12TH        12TH           1 2016-01-01  2016-01-01     0      Friday
# 1   12TH        16TH           1 2016-01-01  2016-01-01     0      Friday
# 2   12TH        24TH           4 2016-01-01  2016-01-01     0      Friday
# 3   12TH        ASHB           4 2016-01-01  2016-01-01     0      Friday
# 4   12TH        BALB           2 2016-01-01  2016-01-01     0      Friday

# %%
# Location bilgisini ayrıştırma
dfinfo['latitude'] = dfinfo['Location'].apply(lambda x: float(x.split(',')[1]))
dfinfo['longitude'] = dfinfo['Location'].apply(lambda x: float(x.split(',')[0]))

# Gereksiz sütunları kaldırma
dfinfo = dfinfo[['Abbreviation', 'Name', 'latitude', 'longitude']]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
img=plt.imread('bart-system-map-weekday')
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import matplotlib.pyplot as plt
#       2 plt.figure(figsize=(10,10))
# ----> 3 img=plt.imread('bart-system-map-weekday')
#       4 plt.imshow(img)
#       5 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2389, in imread(fname, format)
#    2385 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2386 def imread(
#    2387         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2388 ) -> np.ndarray:
# -> 2389     return matplotlib.image.imread(fname, format)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:1525, in imread(fname, format)
#    1518 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1519     # Pillow doesn't handle URLs directly.
#    1520     raise ValueError(
# ...

# %%
dfinfo.head()
# Out:
#   Abbreviation                                 Name   latitude   longitude
# 0         12TH  12th St. Oakland City Center (12TH)  37.803768 -122.271450
# 1         16TH              16th St. Mission (16TH)  37.765062 -122.419694
# 2         19TH              19th St. Oakland (19TH)  37.808350 -122.268602
# 3         24TH              24th St. Mission (24TH)  37.752470 -122.418143
# 4         ASHB                         Ashby (ASHB)  37.852803 -122.270062

# %%
# En yoğun istasyonu bulmak için yolcu sayılarını toplarız
busiest_station = df.groupby('Origin')['Throughput'].sum().idxmax()
busiest_station_count = df.groupby('Origin')['Throughput'].sum().max()
print(f"En yoğun BART istasyonu {busiest_station} olup {busiest_station_count} yolcudur.")
# Out:
# En yoğun BART istasyonu MONT olup 16107314 yolcudur.

# %%
least_popular_route = df.groupby(['Origin', 'Destination'])['Throughput'].sum().idxmin()
least_popular_route_count = df.groupby(['Origin', 'Destination'])['Throughput'].sum().min()
print(f"En az popüler BART rotası {least_popular_route} olup {least_popular_route_count} yolcudur.")
# Out:
# En az popüler BART rotası ('WSPR', 'SBRN') olup 40 yolcudur.

# %%
best_time = df[(df['Origin'] == 'BERK') & (df['Destination'] == 'SF')].groupby('hour')['Throughput'].mean().idxmin()
print(f"Berkeley'den SF'ye gitmek için en uygun zaman saat {best_time}:00.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-bc753cef0e64> in <cell line: 1>()
# ----> 1 best_time = df[(df['Origin'] == 'BERK') & (df['Destination'] == 'SF')].groupby('hour')['Throughput'].mean().idxmin()
#       2 print(f"Berkeley'den SF'ye gitmek için en uygun zaman saat {best_time}:00.")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in idxmin(self, axis, skipna, *args, **kwargs)
#    2458         # error: Argument 1 to "argmin" of "IndexOpsMixin" has incompatible type "Union
#    2459         # [int, Literal['index', 'columns']]"; expected "Optional[int]"
# -> 2460         i = self.argmin(axis, skipna, *args, **kwargs)  # type: ignore[arg-type]
#    2461         if i == -1:
#    2462             return np.nan
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in argmin(self, axis, skipna, *args, **kwargs)
# ...

# %%
busiest_day = df.groupby('day_of_week')['Throughput'].sum().idxmax()
print(f"Haftanın en yoğun günü {busiest_day}.")
# Out:
# Haftanın en yoğun günü Wednesday.

# %%
late_night_ridership = df[df['hour'] >= 22]['Throughput'].sum()
print(f"Gece geç saatlerde BART'ı kullanan kişi sayısı {late_night_ridership}.")
# Out:
# Gece geç saatlerde BART'ı kullanan kişi sayısı 7049568.

# %%
# Her istasyon arasındaki düz çizgi mesafesini hesaplama:

# %%
import pandas as pd
import numpy as np
from itertools import combinations

# Haversine formülü ile mesafe hesaplama
def haversine(lon1, lat1, lon2, lat2):
    R = 6371
    dlon, dlat = np.radians(lon2 - lon1), np.radians(lat2 - lat1)
    a = np.sin(dlat / 2)**2 + np.cos(np.radians(lat1)) * np.cos(np.radians(lat2)) * np.sin(dlon / 2)**2
    return 2 * R * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

# Mevcut veri çerçevesi dfinfo
# Mesafe hesaplamaları
distances = [(a, b, haversine(dfinfo.loc[dfinfo['Abbreviation'] == a, 'longitude'].values[0],
                              dfinfo.loc[dfinfo['Abbreviation'] == a, 'latitude'].values[0],
                              dfinfo.loc[dfinfo['Abbreviation'] == b, 'longitude'].values[0],
                              dfinfo.loc[dfinfo['Abbreviation'] == b, 'latitude'].values[0]))
             for a, b in combinations(dfinfo['Abbreviation'], 2)]

df_distances = pd.DataFrame(distances, columns=['Station1', 'Station2', 'Distance_km'])
df_distances.head()
# Out:
#   Station1 Station2  Distance_km
# 0     12TH     16TH    13.720175
# 1     12TH     19TH     0.567617
# 2     12TH     24TH    14.097927
# 3     12TH     ASHB     5.453806
# 4     16TH     19TH    14.123076

# %%
# BART ile iki istasyon arasında işe gidip gelen kişi sayısını tahmin edebilecek bir model oluşturma:

# %%
# df ve dfinfo veri çerçevelerini birleştirme
df_combined = df.merge(dfinfo, left_on='Origin', right_on='Abbreviation', suffixes=('', '_origin'))
df_combined = df_combined.merge(dfinfo, left_on='Destination', right_on='Abbreviation', suffixes=('', '_destination'))

# Gerekli sütunları seçme
df_combined = df_combined[['Origin', 'Destination', 'Throughput', 'date', 'hour', 'day_of_week',
                           'latitude', 'longitude', 'latitude_destination', 'longitude_destination']]

# %%
df_combined.head()
# Out:
#   Origin Destination  Throughput        date  hour day_of_week   latitude  \
# 0   12TH        12TH           1  2016-01-01     0      Friday  37.803768
# 1   12TH        12TH           1  2016-01-01     1      Friday  37.803768
# 2   12TH        12TH           4  2016-01-01     2      Friday  37.803768
# 3   12TH        12TH           1  2016-01-01    11      Friday  37.803768
# 4   12TH        12TH           1  2016-01-01    12      Friday  37.803768
#
#    longitude  latitude_destination  longitude_destination
# 0 -122.27145             37.803768             -122.27145
# 1 -122.27145             37.803768             -122.27145
# 2 -122.27145             37.803768             -122.27145
# 3 -122.27145             37.803768             -122.27145
# 4 -122.27145             37.803768             -122.27145

# %%
# date sütununu çıkarma
df_combined = df_combined.drop(columns=['date'])

# %%
# Kategorik verileri sayısal verilere dönüştürme
df_combined = pd.get_dummies(df_combined, columns=['Origin', 'Destination', 'day_of_week'], drop_first=True)
df_combined = df_combined.astype(int)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression

# %%
x = df_combined.drop(columns=['Throughput'])

# %%
y= df_combined[['Throughput']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.20, random_state =42)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
tahmin=lr.predict(x_test)

# %%
r2_score(y_test,tahmin)
# Out:
# 0.05248918047465234

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",100)

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error


def algo_test(x,y):
        #Bütün modelleri tanımlıyorum
        L=LinearRegression()
        R=Ridge()
        Lass=Lasso()
        E=ElasticNet()
        ETR=ExtraTreeRegressor()
        GBR=GradientBoostingRegressor()
        kn=KNeighborsRegressor()
        dt=DecisionTreeRegressor()
        xgb=XGBRegressor()


        algos=[L,R,Lass,E,ETR,GBR,kn,dt,xgb]
        algo_names=['Linear','Ridge','Lasso','ElasticNet','Extra Tree','Gradient Boosting','KNeighborsRegressor','Decision Tree','XGBRegressor']

        x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.2,random_state=42)

        r_squared= []
        rmse= []
        mae= []

        #Hata ve doğruluk oranlarını bir tablo haline getirmek için bir dataframe oluşturuyorum
        result=pd.DataFrame(columns=['R_Squared','RMSE','MAE'],index=algo_names)


        for algo in algos:
            p=algo.fit(x_train,y_train).predict(x_test)
            r_squared.append(r2_score(y_test,p))
            rmse.append(mean_squared_error(y_test,p)**.5)
            mae.append(mean_absolute_error(y_test,p))



        #result adlı tabloya doğruluk ve hata oranlarımı yerleştiriyorum
        result.R_Squared=r_squared
        result.RMSE=rmse
        result.MAE=mae

       #oluşturduğum result tablosunu doğruluk oranına (r2_score) göre sıralayıp dönüyor
        rtable=result.sort_values('R_Squared',ascending=False)
        return rtable

# %%
algo_test(x, y)
# Out:
#                      R_Squared       RMSE       MAE
# Decision Tree         0.790765   5.941438  3.140069
# Extra Tree            0.790734   5.941880  3.140601
# XGBRegressor          0.772650   6.193302  3.487008
# KNeighborsRegressor   0.715199   6.931789  3.519304
# Gradient Boosting     0.424270   9.855624  6.070907
# Ridge                 0.052489  12.643485  8.111626
# Linear                0.052489  12.643486  8.111632
# ElasticNet            0.007791  12.938272  8.381156
# Lasso                 0.006959  12.943695  8.390023

# %%
# Deep Learning ile hesaplama

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf

# %%
model = Sequential()
model.add(Dense(8, activation = 'relu'))
model.add(Dense(120, activation = 'relu'))
model.add(Dense(80, activation = 'relu'))
model.add(Dense(60, activation = 'relu'))
model.add(Dense(4, activation = 'relu'))
model.add(Dense(1))
model.compile(loss = 'mse', optimizer = 'adam')

# %%
history = model.fit(x_train, y_train, validation_data = (x_test,y_test), batch_size = 128, epochs = 50)
# Out:
# Epoch 1/50
# 1338/1338 [==============================] - 8s 6ms/step - loss: 163.4644 - val_loss: 152.8781
# Epoch 2/50
# 1338/1338 [==============================] - 7s 5ms/step - loss: 157.3220 - val_loss: 141.6288
# Epoch 3/50
# 1338/1338 [==============================] - 5s 4ms/step - loss: 150.0240 - val_loss: 130.9745
# Epoch 4/50
# 1338/1338 [==============================] - 9s 7ms/step - loss: 141.7866 - val_loss: 135.6162
# Epoch 5/50
# 1338/1338 [==============================] - 5s 3ms/step - loss: 137.9657 - val_loss: 128.6107
# Epoch 6/50
# 1338/1338 [==============================] - 5s 4ms/step - loss: 134.8476 - val_loss: 121.0184
# Epoch 7/50
# 1338/1338 [==============================] - 9s 7ms/step - loss: 134.4527 - val_loss: 119.2993
# Epoch 8/50
# 1338/1338 [==============================] - 5s 4ms/step - loss: 133.4073 - val_loss: 121.2929
# Epoch 9/50
# 1338/1338 [==============================] - 5s 3ms/step - loss: 132.0793 - val_loss: 122.4932
# ...

# %%
tahmin = model.predict(x_test)
# Out:
# 1338/1338 [==============================] - 7s 4ms/step

# %%
r2_score(y_test, tahmin)
# Out:
# 0.5238167016061608
